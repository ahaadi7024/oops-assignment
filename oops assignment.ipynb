# %% [markdown]
# python oops quistions

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# OOP is a way of programming where we use classes and objects to make our code more organized and reusable.
#
# 2. What is a class in OOP?
#
# A class is like a blueprint that defines how objects will look and behave. It contains variables and functions related to an object.
#
# 3. What is an object in OOP?
#
# An object is an example of a class. It has its own data and can use the functions defined in the class.
#
# 4. What is the difference between abstraction and encapsulation?
#
# Abstraction hides unnecessary details and shows only the main part.
#
# Encapsulation means keeping data and methods together inside a class.
#
# 5. What are dunder methods in Python?
#
# Dunder methods are special methods that start and end with double underscores like __init__, __str__, etc.
# Example: __init__ runs when we create an object.
#
# 6. Explain the concept of inheritance in OOP.
#
# Inheritance means one class (child) can use the properties and methods of another class (parent).
# It helps to reuse code.
#
# 7. What is polymorphism in OOP?
#
# Polymorphism means one thing behaving in many ways.
#
# 8. How is encapsulation achieved in Python?
#
# Encapsulation is done by using private (__) and protected (_) variables so they can’t be accessed directly from outside the class.
#
# 9. What is a constructor in Python?
#
# A constructor is a special method called __init__() that runs automatically when an object is made.
#
# 10. What are class and static methods in Python?
#
# Class methods use @classmethod and can change class variables.
#
# Static methods use @staticmethod and don’t depend on class or object data.
#
# 11. What is method overloading in Python?
#
# Python doesn’t support overloading directly, but we can do it using default or variable arguments in a function.
#
# 12. What is method overriding in OOP?
#
# When a child class has the same method name as its parent class, it replaces or overrides the parent version.
#
# 13. What is a property decorator in Python?
#
# @property is used to make a method act like a variable. It is useful for reading values without calling the method directly.
#
# 14. Why is polymorphism important in OOP?
#
# It helps in writing flexible code that works for different objects in the same way, saving time and making code simple.
#
#
# 15. What is an abstract class in Python?
#
# An abstract class is a class that cannot be used to make objects directly. It only provides a base for other classes using the abc module.
#
#
# 16. What are the advantages of OOP?
#
# Reuse of code
#
# Easy to manage and understand
#
# Real-world modeling
#
# Flexibility and scalability
#
# 17. What is the difference between a class variable and an instance variable?
#
# Class variable: shared by all objects.
#
# Instance variable: different for each object.
#
#
# 18. What is multiple inheritance in Python?
#
# When a class inherits from more than one parent class.
# Example: class C(A, B):
#
#
# 19. Explain the purpose of __str__ and __repr__ methods in Python.
#
# str→ Used for user-friendly output.
# repr → Used for developer/debugging output.
#
#
# 20. What is the significance of the super() function in Python?
#
# super() is used to call methods from the parent class inside the child class.
#
#
# 21. What is the significance of the __del__ method in Python?
#
# __del__() is a destructor. It runs when an object is deleted or program ends.
#
#
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
# @staticmethod → Doesn’t use class or object data.
#
# @classmethod → Works with the class and uses cls.
#
#
# 23. How does polymorphism work in Python with inheritance?
#
# In inheritance, the child class can redefine a method from the parent class, giving it a new behavior — this is polymorphism.
#
#
# 24. What is method chaining in Python OOP?
#
# Method chaining means calling multiple methods in one line.
# Example: obj.start().run().stop()
#
#
# 25. What is the purpose of the __call__ method in Python?
#
# __call__() makes an object callable like a function.
# Example:
#
# obj()
#
# will call obj.__call__().

# %% [markdown]
# PRACTICAL QUISTIONS

# %% [markdown]
#   1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()
# Out:
# Bark!

# %% [markdown]
#  2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth
    def area(self):
        return self.length * self.breadth

c = Circle(5)
r = Rectangle(4, 6)
print("Circle area:", c.area())
print("Rectangle area:", r.area())
# Out:
# Circle area: 78.5
# Rectangle area: 24

# %% [markdown]
#  3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, model):
        super().__init__(type)
        self.model = model

class ElectricCar(Car):
    def __init__(self, type, model, battery):
        super().__init__(type, model)
        self.battery = battery

ec = ElectricCar("Four Wheeler", "Tesla", "100kWh")
print(ec.type, ec.model, ec.battery)
# Out:
# Four Wheeler Tesla 100kWh

# %% [markdown]
#  4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Birds can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly")

for bird in [Sparrow(), Penguin()]:
    bird.fly()
# Out:
# Sparrow flies high
# Penguins cannot fly

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient funds")

    def check_balance(self):
        print("Balance:", self.__balance)

acc = BankAccount(1000)
acc.deposit(500)
acc.withdraw(200)
acc.check_balance()
# Out:
# Balance: 1300

# %% [markdown]
#  6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Playing an instrument")

class Guitar(Instrument):
    def play(self):
        print("Playing guitar")

class Piano(Instrument):
    def play(self):
        print("Playing piano")

for i in [Guitar(), Piano()]:
    i.play()
# Out:
# Playing guitar
# Playing piano

# %% [markdown]
#  7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5, 3))
print(MathOperations.subtract_numbers(10, 4))
# Out:
# 8
# 6

# %% [markdown]
#  8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        print("Total persons:", cls.count)

p1 = Person("Ali")
p2 = Person("Sara")
Person.total_persons()
# Out:
# Total persons: 2

# %% [markdown]
#  9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %% [markdown]
#  10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)
print(v1 + v2)
# Out:
# (6, 8)

# %% [markdown]
#  11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example usage:
p1 = Person("Alice", 30)
p1.greet()

p2 = Person("Bob", 24)
p2.greet()
# Out:
# Hello, my name is Alice and I am 30 years old.
# Hello, my name is Bob and I am 24 years old.

# %% [markdown]
#  12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

# Example usage:
s1 = Student("John", [90, 85, 92, 78])
print(f"{s1.name}'s average grade: {s1.average_grade():.2f}")

s2 = Student("Jane", [75, 88, 80])
print(f"{s2.name}'s average grade: {s2.average_grade():.2f}")

s3 = Student("Mike", [])
print(f"{s3.name}'s average grade: {s3.average_grade():.2f}")
# Out:
# John's average grade: 86.25
# Jane's average grade: 81.00
# Mike's average grade: 0.00

# %% [markdown]
#  13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def __init__(self, length=0, width=0):
        self.length = length
        self.width = width

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example usage:
r1 = Rectangle()
r1.set_dimensions(5, 10)
print(f"Rectangle 1 Area: {r1.area()}")

r2 = Rectangle(7, 3)
print(f"Rectangle 2 Area: {r2.area()}")
# Out:
# Rectangle 1 Area: 50
# Rectangle 2 Area: 21

# %% [markdown]
#  14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# Example usage:
emp = Employee(160, 25) # 160 hours, $25/hour
print(f"Employee salary: ${emp.calculate_salary():.2f}")

manager = Manager(160, 30, 500) # 160 hours, $30/hour, $500 bonus
print(f"Manager salary: ${manager.calculate_salary():.2f}")
# Out:
# Employee salary: $4000.00
# Manager salary: $5300.00

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Example usage:
p1 = Product("Laptop", 1200, 1)
print(f"Product: {p1.name}, Total Price: ${p1.total_price():.2f}")

p2 = Product("Mouse", 25, 3)
print(f"Product: {p2.name}, Total Price: ${p2.total_price():.2f}")
# Out:
# Product: Laptop, Total Price: $1200.00
# Product: Mouse, Total Price: $75.00

# %% [markdown]
#  16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo!"

class Sheep(Animal):
    def sound(self):
        return "Baa!"

# Example usage:
cow = Cow()
sheep = Sheep()

print(f"Cow says: {cow.sound()}")
print(f"Sheep says: {sheep.sound()}")
# Out:
# Cow says: Moo!
# Sheep says: Baa!

# %% [markdown]
#  17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Published: {self.year_published}"

# Example usage:
b1 = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)
print(b1.get_book_info())

b2 = Book("1984", "George Orwell", 1949)
print(b2.get_book_info())
# Out:
# Title: The Great Gatsby, Author: F. Scott Fitzgerald, Published: 1925
# Title: 1984, Author: George Orwell, Published: 1949

# %% [markdown]
#  18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

house = House("123 Main St", 300000)
print(f"House: {house.address}, Price: ${house.price}")

mansion = Mansion("456 Grand Ave", 1500000, 10)
print(f"Mansion: {mansion.address}, Price: ${mansion.price}, Rooms: {mansion.number_of_rooms}")
# Out:
# House: 123 Main St, Price: $300000
# Mansion: 456 Grand Ave, Price: $1500000, Rooms: 10
